# %%
import os
print(os.getcwd())
print(sorted(os.listdir()))
# Out:
# /Users/raceee-g/Desktop/Markov_Switching_AR
# ['.DS_Store', '.ipynb_checkpoints', 'Untitled1.ipynb', '__init__.py', '__pycache__', 'adapter.py', 'data', 'model_utils.ipynb', 'model_utils.py', 'test_basic.ipynb', 'untitled', 'untitled1']

# %%
from adapter import YFinanceAdapter
from model_utils import prepare_return_data

print("imports successful")
# Out:
# imports successful

# %%
adapter = YFinanceAdapter()

df = prepare_return_data(
    ticker="SPY",
    start_date="2019-01-01",
    end_date="2025-01-01",
    adapter=adapter
)

df.head()
# Out:
# Loading data from cache...
#                  price  log_price    return
# Date
# 2019-01-03  219.028152   5.389200 -0.024152
# 2019-01-04  226.364700   5.422147  0.032947
# 2019-01-07  228.149445   5.430001  0.007853
# 2019-01-08  230.292969   5.439352  0.009351
# 2019-01-09  231.369278   5.444015  0.004663

# %%
df.tail()
# Out:
#                  price  log_price    return
# Date
# 2024-12-24  592.702148   6.384692  0.011054
# 2024-12-26  592.741577   6.384759  0.000067
# 2024-12-27  586.502075   6.374176 -0.010582
# 2024-12-30  579.809082   6.362699 -0.011477
# 2024-12-31  577.699768   6.359054 -0.003645

# %%
df["return"].plot(figsize=(12, 4), title="SPY Log Returns")
# Out:
# <Axes: title={'center': 'SPY Log Returns'}, xlabel='Date'>

# %%
df.describe()
# Out:
#              price    log_price       return
# count  1509.000000  1509.000000  1509.000000
# mean    381.399410     5.915253     0.000627
# std      90.613546     0.240915     0.012545
# min     204.944855     5.322741    -0.115887
# 25%     300.077393     5.704040    -0.004395
# 50%     386.865051     5.958076     0.000905
# 75%     429.974518     6.063726     0.006876
# max     597.109375     6.392100     0.086731
